# %% [markdown]
# <a href="https://colab.research.google.com/github/Matheus2703/pcd-aula03/blob/main/atividades_aula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git config --global user.name Matheus2703
# !git config --global user.email matheus.ledur2703@gmail.com
# !git config --global init.defaultBranch main

# %%
# !git config --global --list
# Out:
# user.name=Matheus2703
# user.email=matheus.ledur2703@gmail.com
# init.defaultbranch=main

# %%
nome = input('Digite seu nome: ')

nota1 = float (input('Digite a primeira a nota: '))
nota2 = float (input('Digite a segunda a nota: '))
nota3 = float (input('Digite a terceira a nota: '))


media_notas = (nota1 + nota2 + nota3)/3

print(f'Olá {nome}!')
print(f'Suas notas são: {nota1}, {nota2} e {nota3}')
print(f'A média das suas notas é: {media_notas}')
# Out:
# Digite seu nome: Matheus
# Digite a primeira a nota: 5
# Digite a segunda a nota: 7
# Digite a terceira a nota: 9
# Olá Matheus!
# Suas notas são: 5.0, 7.0 e 9.0
# A média das suas notas é: 7.0
